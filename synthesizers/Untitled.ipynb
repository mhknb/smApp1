# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
import os


# os.chdir("/home/hknb/project1/cpgan_hb/")
os.chdir("C:/Users/mheme/OneDrive/Desktop/smGAN-main/smGAN-main/synthesizers/tablegan")
# os.chdir("C:/Users/mheme/OneDrive/Desktop/smGAN-main/smGAN-main/synthesizers/tvae")
# !ls
# !dir

# %%
# tablegan
# sdv_tvae

# %%
# !python tablegan.py \
    -name exp1 \
    -data census \
    -ep 10 \
    -s 123 \
    --train "True" \
    --evaluate "True" \
    --sample "True" \
    --subset_size 16281 \
    --sample_size 1000 \
    --eval_retries 2
# Out:
# exp_name:exp1
# dataset:adult
# subset_size:16281
# random_state:123
# eval_iter:100
# save_after:100
# train:True
# evaluate:True
# sample:True
# resume:False
# if_validate:True
# batch_size:500
# epochs:10
# test_size:5000
# sample_size:1000
# eval_retries:2
# use_sampler:False
# numerical_preprocess:minmax
# discrete_preprocess:label
# max_clusters:10
# covariance_type:full
# random_dim:100
# num_channels:64
# lr:1e-05
# class_target:income
# DataFrame saved as 'transformeed_data.csv' at: C:\Users\mheme\OneDrive\Desktop\smGAN-main\smGAN-main\synthesizers\tablegan\results\transformeed_data.csv
# ****************************************************************************************************
# size of train dataset: 16281
# dim of train dataset: 15
# batch size: 500
# x_dim: 15, y_dim: 0
# Epoch 1/10 Disc/Gen 1.00/12.11 Fake/Real/Base (F1) 0.49/0.05/0.68 Fake/Real (Dist) 454445.92/0.51
# ...
